# %% [markdown]
# [학습목표]<br>
# 그래프의 영역을 색으로 채워 그래프의 특정 부분을 강조할 수 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 그래프에 한글폰트 설정
plt.rcParams['font.family']='d2coding'

# 그래프에 마이너스 기호 깨지는 문제 해결
plt.rcParams['axes.unicode_minus'] = False

# %%
# 그리드 스타일 : 라인스타일'--', 투명도0.3
plt.rcParams['grid.linestyle'] = '--'
plt.rcParams['grid.alpha'] = 0.3

# 폰트 사이즈 12
plt.rcParams['font.size']=12

# %% [markdown]
# # 그래프 영역 채우기

# %% [markdown]
# ## 가로방향으로 채우기
# * `plt.fill_between(x슬라이싱, y슬라이싱)`
# * 슬라이싱 범위가 같아야 한다.

# %%
x = [1,2,3,4]  
y = [1,4,3,6]

plt.plot(x,y)
plt.fill_between(x[1:3],y[1:3], color='lightblue', alpha=0.5, hatch='/')
plt.show()

# %% [markdown]
# ## 세로방향으로 채우기
# * `plt.fill_betweenx(y슬라이싱, x슬라이싱)`
# * 슬라이싱 범위가 같아야 한다.

# %%
x = [1,2,3,4]
y = [1,4,3,6]
plt.plot(x,y)

plt.fill_betweenx(y[:2], x[:2], color='lightblue', alpha=0.5, hatch='/')
   
plt.show()

# %% [markdown]
# ## 두 그래프 사이의 영역 채우기
# * `plt.fill_between(x슬라이싱, y1슬라이싱, y2슬라이싱)`

# %%
x = [1,2,3,4]
y1 = [1,3,4,6]
y2 = [2,4,7,9]

plt.plot(x,y1, c='skyblue')
plt.plot(x,y2, c='lightcoral')

plt.fill_between(x[1:3], y1[1:3], y2[1:3], color='lightgray', alpha=0.5, hatch='/')
plt.show()

# %% [markdown]
# ## 다각형 채우기
# * `plt.fill([x축의 좌표들],[y축의 좌표들])`

# %%
x = [1,2,3,4]
y = [1,4,3,6]

plt.plot(x,y)
plt.grid(ls='--')
plt.fill([1.75, 2.25, 2.25, 1.75], [3.5, 3.5, 4.5, 4.5], c='lightblue', alpha=0.3)
plt.fill([2.75, 3.25, 3], [2.5, 2.5, 3.5], c='lightpink', alpha=0.3)
plt.show()
